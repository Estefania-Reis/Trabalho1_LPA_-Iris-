# %% [markdown]
# ### Import Library
#
# Dahuluk presiza import library sira nebe presiza hanesan iha input line sira iha kraik:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import DataSet

# %%
#Import DataSet Of Iris
iris=pd.read_csv('iris.csv')

# %%
#Hare Dadus Iris
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ### 1) Dimension
# Dimension ka iha tetun dehan dimensaun nudar aspetu ida nebe kobre hotu atributu, elementu, fenomena, nst. Nune'e liga fali ba dadus iris nebe iha tabela, entaun nia iha linha hamutuk 150 no koluna hamutuk 5.

# %%
print(iris.shape)
# Out:
# (150, 5)

# %% [markdown]
# ### 2) Central Tendency (Count, Mean, Std, Min, Max)
#
# Valor media nebe repressentativu iha estatistikum bolu dehan Tendensia Sentral. No tendesia sentral nudar sasukat atu determina valor uniku nebe iha sentru husi distribuisaun.

# %%
#Couont Of Iris
iris.count()
# Out:
# sepal.length    150
# sepal.width     150
# petal.length    150
# petal.width     150
# variety         150
# dtype: int64

# %%
#Mean Of Iris
iris.mean()
# Out:
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64

# %%
#Std Of Iris
iris.std()
# Out:
# sepal.length    0.828066
# sepal.width     0.435866
# petal.length    1.765298
# petal.width     0.762238
# dtype: float64

# %%
#Max Of Iris
iris.max()
# Out:
# sepal.length          7.9
# sepal.width           4.4
# petal.length          6.9
# petal.width           2.5
# variety         Virginica
# dtype: object

# %%
#Min Of Iris
iris.min()
# Out:
# sepal.length       4.3
# sepal.width          2
# petal.length         1
# petal.width        0.1
# variety         Setosa
# dtype: object

# %% [markdown]
# ### 3) Info
#
# Informasaun ba dadus sira.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal.length    150 non-null float64
# sepal.width     150 non-null float64
# petal.length    150 non-null float64
# petal.width     150 non-null float64
# variety         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %% [markdown]
# ### 4) Check Null Values
#
# Atu hare valor nebe null iha dadus

# %%
iris.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %% [markdown]
# ### 5) Data Dispersion (Range, Corr)

# %% [markdown]
# #### 5.1) Range of iris

# %%
#Range of sepal.length

print(iris['sepal.length'].max()-iris['sepal.length'].min())
# Out:
# 3.6000000000000005

# %%
#Range of Sepal.width

print(iris['sepal.width'].max()-iris['sepal.width'].min())
# Out:
# 2.4000000000000004

# %%
#Range of petal.length

print(iris['petal.length'].max()-iris['petal.length'].min())
# Out:
# 5.9

# %%
#Range of petal.width

print(iris['petal.width'].max()-iris['petal.width'].min())
# Out:
# 2.4

# %% [markdown]
# #### 5.2) Correlation of iris

# %%
print(iris.corr())
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ### 6) Visualizing

# %% [markdown]
# #### 6.1.1) Histogram of Iris (sepal.length)

# %%
sns.FacetGrid(iris, hue= 'variety', height= 5)\
   .map(sns.distplot, "sepal.length")\
   .add_legend()
plt.show()

# %% [markdown]
# #### 6.1.2) Histogram of Iris (sepal.width)

# %%
sns.FacetGrid(iris, hue= 'variety', height= 5)\
   .map(sns.distplot, "sepal.width")\
   .add_legend()
plt.show()

# %% [markdown]
# #### 6.1.3) Histogram of Iris (petal.length)

# %%
sns.FacetGrid(iris, hue= 'variety', height= 5)\
   .map(sns.distplot, "petal.length")\
   .add_legend()
plt.show()

# %% [markdown]
# #### 6.1.4) Histogram of Iris (petal.width)

# %%
sns.FacetGrid(iris, hue= 'variety', height= 5)\
   .map(sns.distplot, "petal.width")\
   .add_legend()
plt.show()

# %% [markdown]
# #### 6.2.1) Box Plot of Iris (sepal.length)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x= 'variety', y= 'sepal.length', data= iris)
plt.show()

# %% [markdown]
# #### 6.2.2) Box Plot of Iris (sepal.width)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x= 'variety', y= 'sepal.width', data= iris)
plt.show()

# %% [markdown]
# #### 6.2.3) Box Plot of Iris (petal.length)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x= 'variety', y= 'petal.length', data= iris)
plt.show()

# %% [markdown]
# #### 6.2.4) Box Plot of Iris (petal.width)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x= 'variety', y= 'petal.width', data= iris)
plt.show()
